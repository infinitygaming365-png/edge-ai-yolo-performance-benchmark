# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
results = model("https://ultralytics.com/images/bus.jpg", save=True)
# Out:
# ...
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 90.0ms
# Speed: 13.3ms preprocess, 90.0ms inference, 39.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict

# %%
from PIL import Image

Image.open("runs/detect/predict/bus.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=810x1080>

# %%
import time
...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
import time

runs = 5
times = []

for i in range(runs):
    start = time.time()
    results = model("https://ultralytics.com/images/bus.jpg")
    end = time.time()

    inference_time = end - start
    times.append(inference_time)

    print(f"Run {i+1}: {inference_time:.4f} seconds")

avg_time = sum(times) / len(times)
fps = 1 / avg_time

print("\nAverage inference time:", avg_time)
print("Approx FPS:", fps)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 8.2ms
# Speed: 3.4ms preprocess, 8.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Run 1: 0.0846 seconds
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Run 2: 0.0204 seconds
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Run 3: 0.0209 seconds
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 6.6ms
# ...

# %%
import time
from ultralytics import YOLO

models = ["yolov8n.pt", "yolov8s.pt", "yolov8m.pt"]

for model_name in models:
    print(f"\nTesting {model_name}")

    model = YOLO(model_name)

    runs = 5
    times = []

    for i in range(runs):
        start = time.time()
        results = model("https://ultralytics.com/images/bus.jpg")
        end = time.time()

        inference_time = end - start
        times.append(inference_time)

    avg_time = sum(times) / len(times)
    fps = 1 / avg_time

    print(f"Average inference time: {avg_time:.4f} sec")
    print(f"Approx FPS: {fps:.2f}")
# Out:
# Testing yolov8n.pt
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 10.4ms
# Speed: 5.4ms preprocess, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 8.2ms
# Speed: 3.6ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 7.9ms
# Speed: 3.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 9.0ms
# Speed: 4.1ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# ...

# %%
import time
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

sizes = [320, 640, 1280]

for size in sizes:
    print(f"\nTesting resolution: {size}")

    runs = 5
    times = []

    for i in range(runs):
        start = time.time()
        results = model("https://ultralytics.com/images/bus.jpg", imgsz=size)
        end = time.time()

        inference_time = end - start
        times.append(inference_time)

    avg_time = sum(times) / len(times)
    fps = 1 / avg_time

    print(f"Average inference time: {avg_time:.4f} sec")
    print(f"Approx FPS: {fps:.2f}")
# Out:
# Testing resolution: 320
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 49.9ms
# Speed: 1.2ms preprocess, 49.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 256)
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 256)
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 6.5ms
# Speed: 0.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 256)
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 320x256 3 persons, 1 bus, 6.0ms
# Speed: 0.9ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 256)
#
# ...

# %%
import matplotlib.pyplot as plt

# Data from your experiment
resolutions = [320, 640, 1280]
fps_values = [22.6, 42.7, 21.9]

plt.figure()
plt.plot(resolutions, fps_values, marker='o')
plt.title("FPS vs Image Resolution (YOLOv8n on T4)")
plt.xlabel("Resolution")
plt.ylabel("FPS")
plt.show()
